# %%
import numpy as np
from keras.layers import LSTM,Input,Dense,Embedding,Dot,Concatenate,Softmax,TimeDistributed
from keras.models import Model
import random
from keras.models import load_model
import string
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.callbacks import EarlyStopping

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(r"D:\Datasets\spa.txt", 'r', encoding='utf-8') as f:
    lines = f.read().split('\n')
for line in lines[: min(10000, len(lines) - 1)]:
    input_text, target_text = line.split('\t')
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    # target_text = '\t' + target_text + '\n'
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

# %%
def clean_sentence(sentence):
    # Add a space ' ' befor the ? word
    sentence = sentence.replace('?', ' ?')
    # Lower case the sentence
    lower_case_sent = sentence.lower()
    # Strip punctuation
    string_punctuation = string.punctuation
    string_punctuation = string_punctuation.replace('?','')
    # Clean the sentence
    clean_sentence = lower_case_sent.translate(str.maketrans('', '', string_punctuation))
    return clean_sentence

# %%
cleaned_input_sentence = []
cleaned_output_sentence = []

for sentence in input_texts:
    sentence = clean_sentence(sentence)
    cleaned_input_sentence.append(sentence)

for sentence in target_texts:
    sentence = clean_sentence(sentence)
    sentence = '_start_ ' + sentence + ' _end_'
    cleaned_output_sentence.append(sentence)

# %%
cleaned_output_sentence
# Out:
# ['_start_ ve _end_',
#  '_start_ vete _end_',
#  '_start_ vaya _end_',
#  '_start_ váyase _end_',
#  '_start_ hola _end_',
#  '_start_ ¡corre _end_',
#  '_start_ corred _end_',
#  '_start_ ¿quién ? _end_',
#  '_start_ ¡fuego _end_',
#  '_start_ ¡incendio _end_',
#  '_start_ ¡disparad _end_',
#  '_start_ ¡ayuda _end_',
#  '_start_ ¡socorro ¡auxilio _end_',
#  '_start_ ¡auxilio _end_',
#  '_start_ ¡salta _end_',
#  '_start_ salte _end_',
#  '_start_ ¡parad _end_',
#  '_start_ ¡para _end_',
#  '_start_ ¡pare _end_',
#  '_start_ ¡espera _end_',
#  '_start_ esperen _end_',
#  '_start_ continúa _end_',
#  '_start_ continúe _end_',
#  '_start_ hola _end_',
#  '_start_ corrí _end_',
#  '_start_ corría _end_',
#  '_start_ lo intento _end_',
#  '_start_ ¡he ganado _end_',
#  '_start_ ¡oh no _end_',
#  '_start_ tomátelo con soda _end_',
#  '_start_ sonríe _end_',
#  '_start_ ¡al ataque _end_',
#  '_start_ ¡atacad _end_',
#  '_start_ levanta _end_',
#  '_start_ ve ahora mismo _end_',
#  '_start_ ¡lo tengo _end_',
#  '_start_ ¿lo pillas ? _end_',
#  '_start_ ¿entendiste ? _end_',
#  '_start_ él corrió _end_',
#  '_start_ métete adentro _end_',
#  '_start_ abrázame _end_',
#  '_start_ me caí _end_',
#  '_start_ yo lo sé _end_',
#  '_start_ salí _end_',
#  '_start_ mentí _end_',
#  '_start_ perdí _end_',
#  '_start_ dimito _end_',
#  '_start_ renuncié _end_',
#  '_start_ estoy trabajando _end_',
#  '_start_ tengo diecinueve _end_',
#  '_start_ estoy levantado _end_',
#  '_start_ escucha _end_',
#  '_start_ escuche _end_',
#  '_start_ escuchen _end_',
#  '_start_ ¡no puede ser _end_',
#  '_start_ de ninguna manera _end_',
#  '_start_ ¡de ninguna manera _end_',
#  '_start_ ¡imposible _end_',
#  '_start_ ¡de ningún modo _end_',
#  '_start_ ¡de eso nada _end_',
#  '_start_ ¡ni cagando _end_',
#  '_start_ ¡mangos _end_',
#  '_start_ ¡minga _end_',
#  '_start_ ¡ni en pedo _end_',
#  '_start_ ¿en serio ? _end_',
#  '_start_ ¿la verdad ? _end_',
#  '_start_ ¡gracias _end_',
#  '_start_ gracias _end_',
#  '_start_ pruébalo _end_',
#  '_start_ lo procuramos _end_',
#  '_start_ ganamos _end_',
#  '_start_ ¿por qué yo ? _end_',
#  '_start_ pregúntale a tom _end_',
#  '_start_ ¡órale _end_',
#  '_start_ mantente en calma _end_',
#  '_start_ estate tranquilo _end_',
#  '_start_ sé justo _end_',
#  '_start_ sean gentiles _end_',
#  '_start_ sé agradable _end_',
#  '_start_ pírate _end_',
#  '_start_ llamame _end_',
#  '_start_ llamadme _end_',
#  '_start_ llámame _end_',
#  '_start_ llámanos _end_',
#  '_start_ entre _end_',
#  '_start_ pase _end_',
#  '_start_ ¡entren _end_',
#  '_start_ ¡órale _end_',
#  '_start_ ándale _end_',
#  '_start_ ¡órale _end_',
#  '_start_ suéltalo _end_',
#  '_start_ agarra a tom _end_',
#  '_start_ bájate _end_',
#  '_start_ salte _end_',
#  '_start_ sal _end_',
#  '_start_ salí _end_',
#  '_start_ salid _end_',
#  '_start_ salgan _end_',
#  '_start_ ¡vete de aquí _end_',
#  '_start_ ¡lárgate _end_',
#  '_start_ ¡salga de aquí _end_',
#  '_start_ ¡largo _end_',
#  '_start_ ¡vete ya _end_',
#  '_start_ ¡órale _end_',
#  '_start_ ¡a la calle _end_',
#  '_start_ ¡vete de aquí _end_',
#  '_start_ ¡lárgate _end_',
#  '_start_ ¡largo _end_',
#  '_start_ ¡vete ya _end_',
#  '_start_ ¡órale _end_',
#  '_start_ lárguese _end_',
#  '_start_ váyase _end_',
#  '_start_ vete a casa _end_',
#  '_start_ vaya despacio _end_',
#  '_start_ ¡hasta luego _end_',
#  '_start_ hasta la vista _end_',
#  '_start_ ¡chau _end_',
#  '_start_ ¡espera _end_',
#  '_start_ ¡espera un momento _end_',
#  '_start_ ¡un segundo _end_',
#  '_start_ agarra fuertemente _end_',
#  '_start_ él vino _end_',
#  '_start_ él renunció _end_',
#  '_start_ ayúdame _end_',
#  '_start_ ayúdame _end_',
#  '_start_ échame una mano _end_',
#  '_start_ ayudame _end_',
#  '_start_ ayúdanos _end_',
#  '_start_ golpea a tom _end_',
#  '_start_ espera _end_',
#  '_start_ resista _end_',
#  '_start_ resiste _end_',
#  '_start_ agarra fuertemente _end_',
#  '_start_ abraza a tom _end_',
#  '_start_ estoy de acuerdo _end_',
#  '_start_ de acuerdo _end_',
#  '_start_ me incliné _end_',
#  '_start_ me he mudado _end_',
#  '_start_ me mudé _end_',
#  '_start_ me trasladé _end_',
#  '_start_ me he trasladado _end_',
#  '_start_ dormí _end_',
#  '_start_ lo intenté _end_',
#  '_start_ iré _end_',
#  '_start_ soy tom _end_',
#  '_start_ estoy gordo _end_',
#  '_start_ soy gorda _end_',
#  '_start_ estoy en forma _end_',
#  '_start_ estoy afectado _end_',
#  '_start_ soy viejo _end_',
#  '_start_ soy tímido _end_',
#  '_start_ estoy mojada _end_',
#  '_start_ está bien _end_',
#  '_start_ soy yo _end_',
#  '_start_ soy yo _end_',
#  '_start_ únete a nosotros _end_',
#  '_start_ sé parte nuestra _end_',
#  '_start_ guárdalo _end_',
#  '_start_ yo también _end_',
#  '_start_ abre _end_',
#  '_start_ ¡perfecto _end_',
#  '_start_ nos vemos _end_',
#  '_start_ muéstramelo _end_',
#  '_start_ enséñamelo _end_',
#  '_start_ mostrame _end_',
#  '_start_ ¡cierra la boca _end_',
#  '_start_ ¡cerrá el pico _end_',
#  '_start_ sáltatelo _end_',
#  '_start_ hasta la vista _end_',
#  '_start_ hasta luego _end_',
#  '_start_ páralo _end_',
#  '_start_ deténlo _end_',
#  '_start_ cógelo _end_',
#  '_start_ decime _end_',
#  '_start_ tom comió _end_',
#  '_start_ tom corrió _end_',
#  '_start_ tom ganó _end_',
#  '_start_ espérame despierto _end_',
#  '_start_ ¡despierta _end_',
#  '_start_ ¡despiértate _end_',
#  '_start_ ¡despertate _end_',
#  '_start_ despierta _end_',
#  '_start_ lávate las manos _end_',
#  '_start_ nos preocupamos _end_',
#  '_start_ lo sabemos _end_',
#  '_start_ perdimos _end_',
#  '_start_ bienvenidos _end_',
#  '_start_ bienvenidas _end_',
#  '_start_ ¿quién comió ? _end_',
#  '_start_ ¿quién corría ? _end_',
#  '_start_ ¿quién corrió ? _end_',
#  '_start_ ¿quién ganó ? _end_',
#  '_start_ ¿quién ha ganado ? _end_',
#  '_start_ ¿por qué no ? _end_',
#  '_start_ corre _end_',
#  '_start_ has ganado _end_',
#  '_start_ ¿estoy gordo ? _end_',
#  '_start_ preguntales _end_',
#  '_start_ pregúntales _end_',
#  '_start_ aparta _end_',
#  '_start_ apártate _end_',
#  '_start_ sé un hombre _end_',
#  '_start_ sé fuerte _end_',
#  '_start_ sé breve _end_',
#  '_start_ sea breve _end_',
#  '_start_ sean breves _end_',
#  '_start_ estate quieto _end_',
#  '_start_ no te muevas _end_',
#  '_start_ ¡llamalo a tomás _end_',
#  '_start_ ¡llámalo a tomás _end_',
#  '_start_ ¡llámenlo a tomás _end_',
#  '_start_ anímate _end_',
#  '_start_ venga _end_',
#  '_start_ ¡cálmate _end_',
#  '_start_ espósale _end_',
#  '_start_ no te vayas _end_',
#  '_start_ continúa _end_',
#  '_start_ encontralo a tomás _end_',
#  '_start_ encuéntralo a tomás _end_',
#  '_start_ encuéntrelo a tomás _end_',
#  '_start_ encuéntrenlo a tomás _end_',
#  '_start_ encuentre a tom _end_',
#  '_start_ encuentren a tom _end_',
#  '_start_ arregla esto _end_',
#  '_start_ ¡vete de aquí _end_',
#  '_start_ ¡lárgate _end_',
#  '_start_ ¡largo _end_',
#  '_start_ ¡vete ya _end_',
#  '_start_ ponte a ello _end_',
#  '_start_ abajo _end_',
#  '_start_ túmbate _end_',
#  '_start_ ¡piérdete _end_',
#  '_start_ ¡vete de aquí _end_',
#  '_start_ ¡lárgate _end_',
#  '_start_ ¡largo _end_',
#  '_start_ ¡vete ya _end_',
#  '_start_ esfúmate _end_',
#  '_start_ ¡despierta _end_',
#  '_start_ ¡piénsalo bien _end_',
#  '_start_ abre los ojos _end_',
#  '_start_ adelante _end_',
#  '_start_ adelante _end_',
#  '_start_ entre _end_',
#  '_start_ entra _end_',
#  '_start_ entren _end_',
#  '_start_ entrá _end_',
#  '_start_ entrad _end_',
#  '_start_ ¡buen trabajo _end_',
#  '_start_ sujeta a tom _end_',
#  '_start_ agárralo _end_',
#  '_start_ diviértanse _end_',
#  '_start_ pásala bien _end_',
#  '_start_ pásenla bien _end_',
#  '_start_ él habló _end_',
#  '_start_ él lo intenta _end_',
#  '_start_ él prueba _end_',
#  '_start_ ayuda a tom _end_',
#  '_start_ ayúdalo _end_',
#  '_start_ hola ¿qué hay ? _end_',
#  '_start_ ey chavales _end_',
#  '_start_ ¿qué pasa troncos ? _end_',
#  '_start_ buenas _end_',
#  '_start_ ¿qué tal os va ? _end_',
#  '_start_ hola por aquí _end_',
#  '_start_ ¡qué encanto _end_',
#  '_start_ ¿qué tan profundo ? _end_',
#  '_start_ ¿cómo de profundo ? _end_',
#  '_start_ hazme el favor _end_',
#  '_start_ compláceme _end_',
#  '_start_ ¡date prisa _end_',
#  '_start_ apresúrate _end_',
#  '_start_ convine _end_',
#  '_start_ acepté _end_',
#  '_start_ accedí _end_',
#  '_start_ soy gorda _end_',
#  '_start_ estoy viejo _end_',
#  '_start_ me lo comí _end_',
#  '_start_ me la comí _end_',
#  '_start_ puedo ir _end_',
#  '_start_ lo hice bien _end_',
#  '_start_ lo hice _end_',
#  '_start_ fracasé _end_',
#  '_start_ lo olvidé _end_',
#  '_start_ me las arreglo _end_',
#  '_start_ lo entiendo _end_',
#  '_start_ lo tengo _end_',
#  '_start_ llamé por teléfono _end_',
#  '_start_ me niego _end_',
#  '_start_ dimito _end_',
#  '_start_ renuncio _end_',
#  '_start_ lo vi _end_',
#  '_start_ sonreí _end_',
#  '_start_ me quedé _end_',
#  '_start_ hablé _end_',
#  '_start_ hablaba _end_',
#  '_start_ charlé _end_',
#  '_start_ charlaba _end_',
#  '_start_ yo lo uso _end_',
#  '_start_ esperé _end_',
#  '_start_ yo pagaré _end_',
#  '_start_ he vuelto _end_',
#  '_start_ estoy de vuelta _end_',
#  '_start_ soy calvo _end_',
#  '_start_ estoy calvo _end_',
#  '_start_ estoy calmado _end_',
#  '_start_ estoy tranquilo _end_',
#  '_start_ he terminado _end_',
#  '_start_ soy bastante facilón _end_',
#  '_start_ soy justo _end_',
#  '_start_ estoy perfectamente _end_',
#  '_start_ ¡soy libre _end_',
#  '_start_ yo soy libre _end_',
#  '_start_ estoy lleno _end_',
#  '_start_ estoy llena _end_',
#  '_start_ ya me llené _end_',
#  '_start_ estoy aquí _end_',
#  '_start_ estoy en casa _end_',
#  '_start_ estoy herido _end_',
#  '_start_ llego tarde _end_',
#  '_start_ soy vago _end_',
#  '_start_ estoy perdida _end_',
#  '_start_ soy malo _end_',
#  '_start_ me toca a mí _end_',
#  '_start_ estoy perfectamente _end_',
#  '_start_ soy pobre _end_',
#  '_start_ soy rica _end_',
#  '_start_ soy rico _end_',
#  '_start_ estoy a salvo _end_',
#  '_start_ estoy enferma _end_',
#  '_start_ soy delgado _end_',
#  '_start_ estoy limpio _end_',
#  '_start_ estoy calentito _end_',
#  '_start_ estoy débil _end_',
#  '_start_ soy listo _end_',
#  '_start_ gané _end_',
#  '_start_ eso ayuda _end_',
#  '_start_ duele _end_',
#  '_start_ funciona _end_',
#  '_start_ es tom _end_',
#  '_start_ es divertido _end_',
#  '_start_ es suyo _end_',
#  '_start_ es nuevo _end_',
#  '_start_ es extraño _end_',
#  '_start_ es viejo _end_',
#  '_start_ es rojo _end_',
#  '_start_ es triste _end_',
#  '_start_ prohibido pasar _end_',
#  '_start_ no entrar _end_',
#  '_start_ besá a tomás _end_',
#  '_start_ besa a tomás _end_',
#  '_start_ besen a tomás _end_',
#  '_start_ déjalo _end_',
#  '_start_ déjame _end_',
#  '_start_ déjanos _end_',
#  '_start_ vamos _end_',
#  '_start_ ¡órale _end_',
#  '_start_ cuidado _end_',
#  '_start_ cásate conmigo _end_',
#  '_start_ ¿puedo ir ? _end_',
#  '_start_ salva a tom _end_',
#  '_start_ ella vino _end_',
#  '_start_ ella murió _end_',
#  '_start_ ella corre _end_',
#  '_start_ ¡sentate _end_',
#  '_start_ siéntate _end_',
#  '_start_ siéntate aquí _end_',
#  '_start_ ¡hable más fuerte _end_',
#  '_start_ habla más fuerte _end_',
#  '_start_ ¡habla más alto _end_',
#  '_start_ prepárate _end_',
#  '_start_ un momento _end_',
#  '_start_ ¡parate _end_',
#  '_start_ ¡de pie _end_',
#  '_start_ no te muevas _end_',
#  '_start_ detén a tom _end_',
#  '_start_ llévate a tom _end_',
#  '_start_ díselo a tom _end_',
#  '_start_ ¡genial _end_',
#  '_start_ ¡órale _end_',
#  '_start_ ellos ganaron _end_',
#  '_start_ tom vino _end_',
#  '_start_ tom ha muerto _end_',
#  '_start_ tom se cayó _end_',
#  '_start_ tom lo sabía _end_',
#  '_start_ tom tenía constancia de ello _end_',
#  '_start_ tom se fue _end_',
#  '_start_ tom mintió _end_',
#  '_start_ tomás miente _end_',
#  '_start_ tom perdió _end_',
#  '_start_ tom pagó _end_',
#  '_start_ tom renunció _end_',
#  '_start_ tom nadó _end_',
#  '_start_ tom lloró _end_',
#  '_start_ tom se ha levantado _end_',
#  '_start_ demasiado tarde _end_',
#  '_start_ confía en mí _end_',
#  '_start_ inténtalo de veras _end_',
#  '_start_ prueba un poco _end_',
#  '_start_ pruebe un poco _end_',
#  '_start_ prueben un poco _end_',
#  '_start_ prueben esto _end_',
#  '_start_ probá esto _end_',
#  '_start_ prueba esto _end_',
#  '_start_ usa esto _end_',
#  '_start_ avísale a tom _end_',
#  '_start_ avísele a tom _end_',
#  '_start_ avísenle a tom _end_',
#  '_start_ avisale a tom _end_',
#  '_start_ mírame _end_',
#  '_start_ vigílame _end_',
#  '_start_ obsérvame _end_',
#  '_start_ obsérvalos _end_',
#  '_start_ obsérvanos _end_',
#  '_start_ estamos de acuerdo _end_',
#  '_start_ lo intentamos _end_',
#  '_start_ iremos _end_',
#  '_start_ estamos bien _end_',
#  '_start_ ¿para qué ? _end_',
#  '_start_ ¡qué divertido _end_',
#  '_start_ ¿quién soy yo ? _end_',
#  '_start_ ¿quién vino ? _end_',
#  '_start_ ¿quién murió ? _end_',
#  '_start_ ¿quién se calló ? _end_',
#  '_start_ ¿quién se cayó ? _end_',
#  '_start_ ¿quién se ha ido ? _end_',
#  '_start_ ¿quién lo ha dejado ? _end_',
#  '_start_ ¿quién nadó ? _end_',
#  '_start_ ¿quién es él ? _end_',
#  '_start_ escríbeme _end_',
#  '_start_ después de ti _end_',
#  '_start_ tú primero _end_',
#  '_start_ usted primero _end_',
#  '_start_ después de usted _end_',
#  '_start_ después de vosotras _end_',
#  '_start_ apunta ¡fuego _end_',
#  '_start_ respóndeme _end_',
#  '_start_ respondedme _end_',
#  '_start_ respóndanme _end_',
#  '_start_ los pájaros vuelan _end_',
#  '_start_ jesús _end_',
#  '_start_ ¡llama a casa _end_',
#  '_start_ cálmate _end_',
#  '_start_ tranquilízate _end_',
#  '_start_ tomátelo con soda _end_',
#  '_start_ bajá un cambio _end_',
#  '_start_ ¿podemos ir ? _end_',
#  '_start_ ¿podemos irnos ? _end_',
#  '_start_ ¿podemos marcharnos ? _end_',
#  '_start_ ¡atrápelo a tomás _end_',
#  '_start_ captúralo _end_',
#  '_start_ captúrenlo _end_',
#  '_start_ atrápenlo _end_',
#  '_start_ atrápalo _end_',
#  '_start_ vuelve _end_',
#  '_start_ vení _end_',
#  '_start_ ven _end_',
#  '_start_ venid aquí _end_',
#  '_start_ ven a casa _end_',
#  '_start_ venid aquí _end_',
#  '_start_ vente _end_',
#  '_start_ veníos _end_',
#  '_start_ venga aquí _end_',
#  '_start_ vuelve pronto _end_',
#  '_start_ hazlo ahora _end_',
#  '_start_ los perros ladran _end_',
#  '_start_ no preguntes _end_',
#  '_start_ no llores _end_',
#  '_start_ ¡no llorés _end_',
#  '_start_ ¡no llores _end_',
#  '_start_ no lloren _end_',
#  '_start_ no mintáis _end_',
#  '_start_ no corras _end_',
#  '_start_ ¡fantástico _end_',
#  '_start_ ¡es estupendo _end_',
#  '_start_ ¡órale _end_',
#  '_start_ tienta esto _end_',
#  '_start_ tiente esto _end_',
#  '_start_ tienten esto _end_',
#  '_start_ tentad esto _end_',
#  '_start_ tentá esto _end_',
#  '_start_ sígueme _end_',
#  '_start_ seguidme _end_',
#  '_start_ síguenos _end_',
#  '_start_ déjalo _end_',
#  '_start_ olvídame _end_',
#  '_start_ olvídate de mí _end_',
#  '_start_ olvídenme _end_',
#  '_start_ olvídense de mí _end_',
#  '_start_ preparaos _end_',
#  '_start_ ve a por ello _end_',
#  '_start_ ve a cogerlo _end_',
#  '_start_ ve a por ello _end_',
#  '_start_ vete a por ello _end_',
#  '_start_ id a por ello _end_',
#  '_start_ entra _end_',
#  '_start_ vete a la cama _end_',
#  '_start_ cógelo _end_',
#  '_start_ agarra esto _end_',
#  '_start_ coge alguno _end_',
#  '_start_ toma algo _end_',
#  '_start_ tome alguno _end_',
#  '_start_ él es viejo _end_',
#  '_start_ él es anciano _end_',
#  '_start_ él se afeitó _end_',
#  '_start_ sonrió _end_',
#  '_start_ él es dj _end_',
#  '_start_ él es veloz _end_',
#  '_start_ él es bueno _end_',
#  '_start_ él es rico _end_',
#  '_start_ es rico _end_',
#  '_start_ acá estoy _end_',
#  '_start_ sostén esto _end_',
#  '_start_ ¡qué horror _end_',
#  '_start_ ¡qué raro _end_',
#  '_start_ ¿cómo está tom ? _end_',
#  '_start_ divierte a tom _end_',
#  '_start_ estoy ocupada _end_',
#  '_start_ estoy lleno _end_',
#  '_start_ estoy llena _end_',
#  '_start_ soy bueno _end_',
#  '_start_ estoy aquí _end_',
#  '_start_ estoy enferma _end_',
#  '_start_ estoy débil _end_',
#  '_start_ te lo ruego _end_',
#  '_start_ te lo suplico _end_',
#  '_start_ puedo volar _end_',
#  '_start_ puedo correr _end_',
#  '_start_ sé correr _end_',
#  '_start_ sé esquiar _end_',
#  '_start_ sentí vergüenza _end_',
#  '_start_ perdí la consciencia _end_',
#  '_start_ quedé inconsciente _end_',
#  '_start_ lo dejé _end_',
#  '_start_ me rendí _end_',
#  '_start_ tiré la toalla _end_',
#  '_start_ cedí _end_',
#  '_start_ te entiendo _end_',
#  '_start_ te pillo _end_',
#  '_start_ ya te pillo _end_',
#  '_start_ me dieron _end_',
#  '_start_ me alcanzaron _end_',
#  '_start_ lo odio _end_',
#  '_start_ me la seca _end_',
#  '_start_ me la baja _end_',
#  '_start_ golpeo a tom _end_',
#  '_start_ eso espero _end_',
#  '_start_ lo sabía _end_',
#  '_start_ me reí _end_',
#  '_start_ me gusta _end_',
#  '_start_ ¡lo adoro _end_',
#  '_start_ me encanta _end_',
#  '_start_ hablo en serio _end_',
#  '_start_ lo digo en serio _end_',
#  '_start_ hablo en serio _end_',
#  '_start_ lo echo en falta _end_',
#  '_start_ lo echo de menos _end_',
#  '_start_ lo añoro _end_',
#  '_start_ lo necesito _end_',
#  '_start_ vi a tom _end_',
#  '_start_ le vi _end_',
#  '_start_ lo vi _end_',
#  '_start_ vi uno _end_',
#  '_start_ vi a uno _end_',
#  '_start_ veía a uno _end_',
#  '_start_ te vi _end_',
#  '_start_ te he visto _end_',
#  '_start_ veo a tom _end_',
#  '_start_ me tropecé _end_',
#  '_start_ yo cocinaré _end_',
#  '_start_ yo guisaré _end_',
#  '_start_ viviré _end_',
#  '_start_ cantaré _end_',
#  '_start_ pararé _end_',
#  '_start_ lo dejaré _end_',
#  '_start_ esperaré _end_',
#  '_start_ aguardaré _end_',
#  '_start_ caminaré _end_',
#  '_start_ andaré _end_',
#  '_start_ voy a trabajar _end_',
#  '_start_ soy un hombre _end_',
#  '_start_ soy un pro _end_',
#  '_start_ estoy solo _end_',
#  '_start_ estoy sola _end_',
#  '_start_ yo estoy solo _end_',
#  '_start_ yo estoy sola _end_',
#  '_start_ estoy enojado _end_',
#  '_start_ estoy enojada _end_',
#  '_start_ estoy despierto _end_',
#  '_start_ soy ciega _end_',
#  '_start_ estoy sin dinero _end_',
#  '_start_ estoy quebrado _end_',
#  '_start_ estoy sin blanca _end_',
#  '_start_ no tengo blanca _end_',
#  '_start_ estoy loco _end_',
#  '_start_ estoy borracho _end_',
#  '_start_ estoy tomada _end_',
#  '_start_ estoy prendida _end_',
#  '_start_ me estoy muriendo _end_',
#  '_start_ soy el primero _end_',
#  '_start_ voy el primero _end_',
#  '_start_ me toca primero _end_',
#  '_start_ yo voy primero _end_',
#  '_start_ soy feliz _end_',
#  '_start_ estoy feliz _end_',
#  '_start_ soy amado _end_',
#  '_start_ soy amada _end_',
#  '_start_ soy obeso _end_',
#  '_start_ estoy listo _end_',
#  '_start_ lo siento _end_',
#  '_start_ yo estoy cansado _end_',
#  '_start_ yo estoy cansada _end_',
#  '_start_ soy tuyo _end_',
#  '_start_ soy tuya _end_',
#  '_start_ soy suyo _end_',
#  '_start_ he perdido _end_',
#  '_start_ ólvidalo _end_',
#  '_start_ no hagas caso _end_',
#  '_start_ ¿está bien tom ? _end_',
#  '_start_ ¿está tom ? _end_',
#  '_start_ ¿es grave ? _end_',
#  '_start_ ¿es malo ? _end_',
#  '_start_ ¿está lejos ? _end_',
#  '_start_ ¿eres tú ? _end_',
#  '_start_ se quemó _end_',
#  '_start_ no lo consiguió _end_',
#  '_start_ falló _end_',
#  '_start_ fracasó _end_',
#  '_start_ es nuevo _end_',
#  '_start_ llovió _end_',
#  '_start_ nevó _end_',
#  '_start_ apesta _end_',
#  '_start_ funcionó _end_',
#  '_start_ son las tres y diez _end_',
#  '_start_ son las 830 _end_',
#  '_start_ es un televisor _end_',
#  '_start_ hace frío _end_',
#  '_start_ está frío _end_',
#  '_start_ está frío _end_',
#  '_start_ está fresco _end_',
#  '_start_ está oscuro _end_',
#  '_start_ ¡está listo _end_',
#  '_start_ está perfecto _end_',
#  '_start_ está bien _end_',
#  '_start_ es bueno _end_',
#  '_start_ está aquí _end_',
#  '_start_ es de ella _end_',
#  '_start_ es tarde _end_',
#  '_start_ es mío _end_',
#  '_start_ es mía _end_',
#  '_start_ es agradable _end_',
#  '_start_ hace buen tiempo _end_',
#  '_start_ vale _end_',
#  '_start_ está bien _end_',
#  '_start_ es nuestro _end_',
#  '_start_ es la nuestra _end_',
#  '_start_ se terminó _end_',
#  '_start_ se acabó _end_',
#  '_start_ ha llegado el momento _end_',
#  '_start_ es la hora _end_',
#  '_start_ es el momento _end_',
#  '_start_ ha llegado la hora _end_',
#  '_start_ ¡es verdad _end_',
#  '_start_ es verdad _end_',
#  '_start_ es mi trabajo _end_',
#  '_start_ guárdalos _end_',
#  '_start_ quédatelos _end_',
#  '_start_ guárdenselos _end_',
#  '_start_ guarda esto _end_',
#  '_start_ guarde esto _end_',
#  '_start_ guardá esto _end_',
#  '_start_ guardad esto _end_',
#  '_start_ guarden esto _end_',
#  '_start_ mantente caliente _end_',
#  '_start_ manténgase caliente _end_',
#  '_start_ mantenete caliente _end_',
#  '_start_ mantenete abrigado _end_',
#  '_start_ mantente abrigado _end_',
#  '_start_ manténgase abrigado _end_',
#  '_start_ manténganse calientes _end_',
#  '_start_ manténganse abrigados _end_',
#  '_start_ dejalo a tomás _end_',
#  '_start_ déjalo a tomás _end_',
#  '_start_ déjelo a tomás _end_',
#  '_start_ ahora márchate _end_',
#  '_start_ ahora vete _end_',
#  '_start_ ahora lárgate _end_',
#  '_start_ ¡déjame marchar _end_',
#  '_start_ ¡suéltame _end_',
#  '_start_ ¡déjeme ir _end_',
#  '_start_ ¡déjeme ir _end_',
#  '_start_ déjame entrar _end_',
#  '_start_ déjeme entrar _end_',
#  '_start_ déjanos entrar _end_',
#  '_start_ comamos _end_',
#  '_start_ veamos _end_',
#  '_start_ ¡intentémoslo _end_',
#  '_start_ túmbate en silencio _end_',
#  '_start_ mantente quieto en el suelo _end_',
#  '_start_ escuchá _end_',
#  '_start_ mirá para otro lado _end_',
#  '_start_ mira para otro lado _end_',
#  '_start_ mire para otro lado _end_',
#  '_start_ miren para otro lado _end_',
#  '_start_ ¡mira hacia atrás _end_',
#  '_start_ mira atrás _end_',
#  '_start_ mire atrás _end_',
#  '_start_ mirad atrás _end_',
#  '_start_ mira aquí _end_',
#  '_start_ mirad aquí _end_',
#  '_start_ miren aquí _end_',
#  '_start_ aflójalo _end_',
#  '_start_ suéltalo _end_',
#  '_start_ suéltala _end_',
#  '_start_ aflójala _end_',
#  '_start_ hazte a un lado _end_',
#  '_start_ deja sitio _end_',
#  '_start_ mueve el culo _end_',
#  '_start_ deja pasar _end_',
#  '_start_ ¡buen tiro _end_',
#  '_start_ ¡por supuesto _end_',
#  '_start_ ¡disparad _end_',
#  '_start_ ¡fuego a discreción _end_',
#  '_start_ ¿perdona ? _end_',
#  '_start_ por favor ve _end_',
#  '_start_ por favor vete _end_',
#  '_start_ por favor márchate _end_',
#  '_start_ por favor váyase _end_',
#  '_start_ póntelo _end_',
#  '_start_ póngaselo _end_',
#  '_start_ lee esto _end_',
#  '_start_ lea esto _end_',
#  '_start_ lean esto _end_',
#  '_start_ leed esto _end_',
#  '_start_ decí hola _end_',
#  '_start_ a mí que me registren _end_',
#  '_start_ véase arriba _end_',
#  '_start_ véase más arriba _end_',
#  '_start_ ¡a por él _end_',
#  '_start_ ¡cogedlo _end_',
#  '_start_ ¡arrestadlo _end_',
#  '_start_ ¡prendedlo _end_',
#  '_start_ ¡capturadlo _end_',
#  '_start_ ¿en serio ? _end_',
#  '_start_ ella lo intentó _end_',
#  '_start_ ella lo probó _end_',
#  '_start_ ella anda _end_',
#  '_start_ ella camina _end_',
#  '_start_ anda _end_',
#  '_start_ ella es candente _end_',
#  '_start_ está como un tren _end_',
#  '_start_ está de toma pan y moja _end_',
#  '_start_ está buena _end_',
#  '_start_ está que cruje _end_',
#  '_start_ firme aquí _end_',
#  '_start_ firma esto _end_',
#  '_start_ firme esto _end_',
#  '_start_ firmen esto _end_',
#  '_start_ firmá esto _end_',
#  '_start_ firmad esto _end_',
#  '_start_ siéntate y no te muevas _end_',
#  '_start_ siéntate y quédate quieto _end_',
#  '_start_ sentate ahí _end_',
#  '_start_ tú mantente _end_',
#  '_start_ quieto _end_',
#  '_start_ más despacio _end_',
#  '_start_ fuera _end_',
#  '_start_ aléjate _end_',
#  '_start_ mantén la calma _end_',
#  '_start_ mantené la calma _end_',
#  '_start_ quedate acá _end_',
#  '_start_ da un paso atrás _end_',
#  '_start_ para aquí _end_',
#  '_start_ párate aquí _end_',
#  '_start_ detente aquí _end_',
#  '_start_ deténgase aquí _end_',
#  '_start_ deténganse aquí _end_',
#  '_start_ paraos aquí _end_',
#  '_start_ parad aquí _end_',
#  '_start_ para eso _end_',
#  '_start_ deténlos _end_',
#  '_start_ párales _end_',
#  '_start_ ¡cuidate _end_',
#  '_start_ ¡te cuidas _end_',
#  '_start_ cuídate _end_',
#  '_start_ cuidaos _end_',
#  '_start_ coge el mío _end_',
#  '_start_ toma el mío _end_',
#  '_start_ asume el mando _end_',
#  '_start_ toma el control _end_',
#  '_start_ encárgate tú _end_',
#  '_start_ toma esto _end_',
#  '_start_ tome esto _end_',
#  '_start_ tomen esto _end_',
#  '_start_ tomá esto _end_',
#  '_start_ ¡gracias _end_',
#  '_start_ gracias a ti _end_',
#  '_start_ gracias _end_',
#  '_start_ eso es _end_',
#  '_start_ soy yo _end_',
#  '_start_ ese soy yo _end_',
#  '_start_ ¿entonces qué ? _end_',
#  '_start_ cayeron _end_',
#  '_start_ se fueron _end_',
#  '_start_ se marcharon _end_',
#  '_start_ se iban _end_',
#  '_start_ perdieron _end_',
#  '_start_ tom se inclinó _end_',
#  '_start_ tom se preocupó _end_',
#  '_start_ tom se preocupaba _end_',
#  '_start_ a tom le importaba _end_',
#  '_start_ tom se preocupa _end_',
#  '_start_ a tom le importa _end_',
#  '_start_ tom lloró _end_',
#  '_start_ tom dormitó _end_',
#  '_start_ tomás condujo _end_',
#  '_start_ tom está bien _end_',
#  '_start_ tom está dentro _end_',
#  '_start_ tom está levantado _end_',
#  '_start_ tom teje _end_',
#  '_start_ tom sabe _end_',
#  '_start_ tom se mudó _end_',
#  '_start_ tom se movió _end_',
#  '_start_ tom se mece _end_',
#  '_start_ tom se quedó _end_',
#  '_start_ tom nada _end_',
#  '_start_ tom juró _end_',
#  '_start_ tomás lo intentó _end_',
#  '_start_ tomás lo intenta _end_',
#  '_start_ tomás votó _end_',
#  '_start_ tom camina _end_',
#  '_start_ tom saludó _end_',
#  '_start_ tomás trabaja _end_',
#  '_start_ tom irá _end_',
#  '_start_ tom está gordo _end_',
#  '_start_ tom está loco _end_',
#  '_start_ tom está triste _end_',
#  '_start_ tom es tímido _end_',
#  '_start_ confía en tom _end_',
#  '_start_ inténtalo de nuevo _end_',
#  '_start_ intentadlo otra vez _end_',
#  '_start_ intenta otra vez _end_',
#  '_start_ pruébatelo _end_',
#  '_start_ espera aquí _end_',
#  '_start_ aguarda aquí _end_',
#  '_start_ esperen aquí _end_',
#  '_start_ esperad aquí _end_',
#  '_start_ vigila a tom _end_',
#  '_start_ ¡abusado _end_',
#  '_start_ podemos ir _end_',
#  '_start_ podemos irnos _end_',
#  '_start_ nos podemos marchar _end_',
#  '_start_ fallamos _end_',
#  '_start_ hemos fallado _end_',
#  '_start_ nos olvidamos _end_',
#  '_start_ lo vimos _end_',
#  '_start_ lo veíamos _end_',
#  '_start_ conversamos _end_',
#  '_start_ nosotros esperamos _end_',
#  '_start_ después veremos _end_',
#  '_start_ ya veremos _end_',
#  '_start_ lo intentaremos _end_',
#  '_start_ ¡hemos ganado _end_',
#  '_start_ ¿qué hay ? _end_',
#  '_start_ ¿a quién le importa ? _end_',
#  '_start_ ¿quién es él ? _end_',
#  '_start_ ¿quién es ? _end_',
#  '_start_ aabe _end_',
#  '_start_ ¿quién se quedó ? _end_',
#  '_start_ ¿quién irá ? _end_',
#  '_start_ ¿quién es tom ? _end_',
#  '_start_ escribe a tom _end_',
#  '_start_ tú maneja _end_',
#  '_start_ tú empieza _end_',
#  '_start_ lo intentaste _end_',
#  '_start_ tú estás perfectamente _end_',
#  '_start_ estás perfectamente _end_',
#  '_start_ más alto _end_',
#  '_start_ apuntad más alto _end_',
#  '_start_ ¡todos a bordo _end_',
#  '_start_ ¿tengo razón ? _end_',
#  '_start_ ¿me equivoco ? _end_',
#  '_start_ ¿estoy equivocada ? _end_',
#  '_start_ ¡respóndale a tomás _end_',
#  '_start_ ¡respondele a tomás _end_',
#  '_start_ ¡respóndanle a tomás _end_',
#  '_start_ ¿tienes dieciocho ? _end_',
#  '_start_ ¿has cumplido dieciocho ? _end_',
#  '_start_ ¿estás bien ? _end_',
#  '_start_ ¿te apuntas ? _end_',
#  '_start_ ¿estás dentro ? _end_',
#  '_start_ ¿estás levantado ? _end_',
#  '_start_ pregúntale a cualquiera _end_',
#  '_start_ preguntadle a cualquiera _end_',
#  '_start_ pregúntele a cualquiera _end_',
#  '_start_ pregúntenle a cualquiera _end_',
#  '_start_ pregunta por aquí _end_',
#  '_start_ pregunta en los alrededores _end_',
#  '_start_ ¡ten cuidado _end_',
#  '_start_ ¡sé cuidadoso _end_',
#  '_start_ estate contento _end_',
#  '_start_ llega a tiempo _end_',
#  '_start_ llegue a tiempo _end_',
#  '_start_ sea paciente _end_',
#  '_start_ sé serio _end_',
#  '_start_ los pájaros cantan _end_',
#  '_start_ los pájaros están cantando _end_',
#  '_start_ traed comida _end_',
#  '_start_ traed ayuda _end_',
#  '_start_ trae vino _end_',
#  '_start_ ¿puedo ir ? _end_',
#  '_start_ ¿puedo venir ? _end_',
#  '_start_ ¿puedo acercarme ? _end_',
#  '_start_ ¿puedo ayudar ? _end_',
#  '_start_ ¿me puedo quedar ? _end_',
#  '_start_ lleva esto _end_',
#  '_start_ comprobad eso _end_',
#  '_start_ comprueba esto _end_',
#  '_start_ escoge uno _end_',
#  '_start_ vuelve otra vez _end_',
#  '_start_ ven solo _end_',
#  '_start_ vente _end_',
#  '_start_ vénganse _end_',
#  '_start_ vení temprano _end_',
#  '_start_ ven temprano _end_',
#  '_start_ vengan temprano _end_',
#  '_start_ venga temprano _end_',
#  '_start_ ¡pásale _end_',
#  '_start_ ¡pásele _end_',
#  '_start_ ¡pásenle _end_',
#  '_start_ entre _end_',
#  '_start_ pase _end_',
#  '_start_ ¡ven rápido _end_',
#  '_start_ ¡vení rápido _end_',
#  '_start_ ven a mí _end_',
#  '_start_ venid a mí _end_',
#  '_start_ ven a nosotros _end_',
#  '_start_ venid a nosotros _end_',
#  '_start_ ¡ya párale _end_',
#  '_start_ ¿fue tom ? _end_',
#  '_start_ ¡pásale _end_',
#  '_start_ ¡pásele _end_',
#  '_start_ ¡pásenle _end_',
#  '_start_ pasa adentro _end_',
#  '_start_ entra de una vez _end_',
#  '_start_ entra ya _end_',
#  '_start_ métete dentro _end_',
#  '_start_ ¿los hombres lloran ? _end_',
#  '_start_ no vengas _end_',
#  '_start_ ¡no saltéis _end_',
#  '_start_ no miréis _end_',
#  '_start_ ¡no os mováis _end_',
#  '_start_ no te muevas _end_',
#  '_start_ no se mueva _end_',
#  '_start_ no se muevan _end_',
#  '_start_ no cantes _end_',
#  '_start_ no canten _end_',
#  '_start_ no pares _end_',
#  '_start_ ¡no hables _end_',
#  '_start_ no hables _end_',
#  '_start_ ¡no esperes _end_',
#  '_start_ ¡no esperen _end_',
#  '_start_ no esperes _end_',
#  '_start_ no grites _end_',
#  '_start_ come despacio _end_',
#  '_start_ ¡comé despacio _end_',
#  '_start_ el fuego quema _end_',
#  '_start_ seguilo a tomás _end_',
#  '_start_ síguelo a tomás _end_',
#  '_start_ sígalo a tomás _end_',
#  '_start_ síganlo a tomás _end_',
#  '_start_ síguele _end_',
#  '_start_ síguelo _end_',
#  '_start_ olvidate de tomás _end_',
#  '_start_ olvídate de tomás _end_',
#  '_start_ olvídese de tomás _end_',
#  '_start_ olvídenlo _end_',
#  '_start_ perdónanos _end_',
#  '_start_ perdónenos _end_',
#  '_start_ consíguete una vida _end_',
#  '_start_ entra _end_',
#  '_start_ vete a la cama _end_',
#  '_start_ déjalo _end_',
#  '_start_ vete a casa _end_',
#  '_start_ váyase a casa _end_',
#  '_start_ ve a ver a tom _end_',
#  '_start_ andá a trabajar _end_',
#  '_start_ dios existe _end_',
#  '_start_ ten fe _end_',
#  '_start_ tened fe _end_',
#  '_start_ tengan fe _end_',
#  '_start_ confíen _end_',
#  '_start_ él salió a comer _end_',
#  '_start_ tosió _end_',
#  '_start_ él se rindió _end_',
#  '_start_ se rindió _end_',
#  '_start_ lo dejó _end_',
#  '_start_ cedió _end_',
#  '_start_ tiró la toalla _end_',
#  '_start_ descolgó _end_',
#  '_start_ él cogió el teléfono _end_',
#  ...]

# %%
max_input_sentence_length = max([len(txt.split()) for txt in cleaned_input_sentence])

max_output_sentence_length = max([len(txt.split()) for txt in cleaned_output_sentence])

# %%
max_input_sentence_length
# Out:
# 6

# %%
max_output_sentence_length
# Out:
# 11

# %% [markdown]
# Tokenization

# %%
tokenizer_x = Tokenizer()
tokenizer_y = Tokenizer()

tokenizer_x.fit_on_texts(cleaned_input_sentence)
tokenizer_y.fit_on_texts(cleaned_output_sentence)

vocab_size_x = len(tokenizer_x.word_index) + 1
vocab_size_y = len(tokenizer_y.word_index) + 1

encoder_data = tokenizer_x.texts_to_sequences(cleaned_input_sentence)
decoder_data = tokenizer_y.texts_to_sequences(cleaned_output_sentence)


padded_encoded_data = pad_sequences(encoder_data,maxlen=max_input_sentence_length,padding="post")
padded_decoded_data = pad_sequences(decoder_data,maxlen=max_output_sentence_length,padding="post")

# %% [markdown]
# Developing endcoder decoder model with attention mechanism

# %%
# encoder

encoder_input = Input(shape=(max_input_sentence_length,),name="encoder_input_layer")
embedding_layer_encoder = Embedding(input_dim=vocab_size_x,output_dim=100,trainable=True,name="encoder_embedding_layer")(encoder_input)
lstm1,state_h1,state_c1 = LSTM(256,return_state=True,return_sequences=True,name="encoder_lstm1")(embedding_layer_encoder)
lstm2,state_h2,state_c2 = LSTM(256,return_state=True,return_sequences=True,name="encoder_lstm2")(lstm1)
encoder_output,h,c = LSTM(256,return_state=True,return_sequences=True,name="encoder_output_layer")(lstm2)

encoder_states = [h,c]

# decoder

decoder_input = Input(shape=(None,),name="decoder_input_layer")
embedding_layer_decoder = Embedding(input_dim=vocab_size_y,output_dim=100,trainable=True,name="decoder_embedding_layer")(decoder_input)
decoder,state_h,state_c = LSTM(256,return_sequences=True,return_state=True,name="decoder_lstm")(embedding_layer_decoder,initial_state=encoder_states)
decoder_states = [state_h,state_c]

# Implementing Attention Mechanism
dot_layer_1 = Dot(axes=(2,2),name="dot_layer_1")([decoder,encoder_output])
activation_layer = Softmax(name="softmax_layer")(dot_layer_1)
dot_layer_2 = Dot(axes=(2,1),name="dot_layer2")([activation_layer,encoder_output])
concatenation_Layer = Concatenate(axis=-1,name="concatenation_layer")([dot_layer_2,decoder])

# output

dense_layer = TimeDistributed(Dense(vocab_size_y,activation='softmax',name="dense_layer"))(concatenation_Layer)
# dense_layer = Dense(units=vocab_size_y,activation='softmax',name="dense_layer")(concatenation_Layer)

model = Model([encoder_input,decoder_input],[dense_layer])

# %%
model.compile(loss="sparse_categorical_crossentropy", optimizer="nadam", metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  encoder_input_layer (Input  [(None, 6)]                  0         []
#  Layer)
#
#  encoder_embedding_layer (E  (None, 6, 100)               236300    ['encoder_input_layer[0][0]']
#  mbedding)
#
#  encoder_lstm1 (LSTM)        [(None, 6, 256),             365568    ['encoder_embedding_layer[0][0
#                               (None, 256),                          ]']
#                               (None, 256)]
#
#  decoder_input_layer (Input  [(None, None)]               0         []
#  Layer)
#
#  encoder_lstm2 (LSTM)        [(None, 6, 256),             525312    ['encoder_lstm1[0][0]']
#                               (None, 256),
#                               (None, 256)]
#
#  decoder_embedding_layer (E  (None, None, 100)            496200    ['decoder_input_layer[0][0]']
#  mbedding)
#
#  encoder_output_layer (LSTM  [(None, 6, 256),             525312    ['encoder_lstm2[0][0]']
#  )                            (None, 256),
#                               (None, 256)]
#
#  decoder_lstm (LSTM)         [(None, None, 256),          365568    ['decoder_embedding_layer[0][0
#                               (None, 256),                          ]',
#                               (None, 256)]                           'encoder_output_layer[0][1]',
#                                                                      'encoder_output_layer[0][2]']
#
#  dot_layer_1 (Dot)           (None, None, 6)              0         ['decoder_lstm[0][0]',
#                                                                      'encoder_output_layer[0][0]']
#
#  softmax_layer (Softmax)     (None, None, 6)              0         ['dot_layer_1[0][0]']
#
#  dot_layer2 (Dot)            (None, None, 256)            0         ['softmax_layer[0][0]',
#                                                                      'encoder_output_layer[0][0]']
#
#  concatenation_layer (Conca  (None, None, 512)            0         ['dot_layer2[0][0]',
#  tenate)                                                             'decoder_lstm[0][0]']
#
#  time_distributed_11 (TimeD  (None, None, 4962)           2545506   ['concatenation_layer[0][0]']
#  istributed)
#
# ==================================================================================================
# Total params: 5059766 (19.30 MB)
# Trainable params: 5059766 (19.30 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
padded_encoded_input_data = padded_encoded_data
padded_decoded_input_data = padded_decoded_data[:,:-1]
padded_decoded_output_data = padded_decoded_data.reshape(padded_decoded_data.shape[0],padded_decoded_data.shape[1],1)[:,1:]

print(padded_encoded_input_data.shape)
print(padded_decoded_input_data.shape)
print(padded_decoded_output_data.shape)
# Out:
# (10000, 6)
# (10000, 10)
# (10000, 10, 1)

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1)

# %%
model.fit([padded_encoded_input_data,padded_decoded_input_data],padded_decoded_data[:,1:],batch_size=32,epochs=100,verbose=1,validation_split=0.2,callbacks=[es])
# Out:
# Epoch 1/100
# 250/250 [==============================] - 19s 76ms/step - loss: 0.1816 - accuracy: 0.9393 - val_loss: 2.2407 - val_accuracy: 0.7562
# Epoch 2/100
# 250/250 [==============================] - 18s 74ms/step - loss: 0.1766 - accuracy: 0.9404 - val_loss: 2.2546 - val_accuracy: 0.7561
# Epoch 2: early stopping
